# %%
import scanpy as sc
import pandas as pd
import numpy as np
import seaborn as sns
import os

import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300

# %%
dsets = pd.read_csv('/Users/tessa/Documents/GitHub/single_cell_perturbation_data/code/tables/scperturb_dataset_info.csv')#, index_col=0)

# %%
#(dsets.index+dsets['dataset_index'])[~(dsets.index + dsets['dataset_index']).isna()]
dsets.iloc[:,1] = dsets.iloc[:,1].fillna('')
# want to change index to those when second col exists

# %%
dsets.index = (dsets.iloc[:,0]+'_'+dsets.iloc[:,1]).str.rstrip('_')

# %%
dsets.drop(index="FrangiehIzar2021_RNA", inplace = True)
dsets.drop(index = "PapalexiSatija2021_eccite_arrayed_RNA", inplace=True)
dsets.drop(index = "PapalexiSatija2021_eccite_RNA", inplace=True)

# %%
# correct paired datasets

dsets.loc[["FrangiehIzar2021_protein","PapalexiSatija2021_eccite_arrayed_protein",
          "PapalexiSatija2021_eccite_protein"],"Modality = Data type"] = "RNA + protein"

# %%
dsets
# Out:
#                                                    Index (=FirstauthorLastauthorYear)  \
# AdamsonWeissman2016_GSM2406675_10X001                             AdamsonWeissman2016
# AdamsonWeissman2016_GSM2406677_10X005                             AdamsonWeissman2016
# AdamsonWeissman2016_GSM2406681_10X010                             AdamsonWeissman2016
# AissaBenevolenskaya2021                                       AissaBenevolenskaya2021
# ChangYe2021                                                               ChangYe2021
# DatlingerBock2017                                                   DatlingerBock2017
# DatlingerBock2021                                                   DatlingerBock2021
# DixitRegev2016                                                         DixitRegev2016
# FrangiehIzar2021_protein                                             FrangiehIzar2021
# GasperiniShendure2019_atscale                                   GasperiniShendure2019
# GasperiniShendure2019_highMOI                                   GasperiniShendure2019
# GasperiniShendure2019_lowMOI                                    GasperiniShendure2019
# GehringPachter2019                                                 GehringPachter2019
# Liscovitch-BrauerSanjana2021_K562_1                      Liscovitch-BrauerSanjana2021
# Liscovitch-BrauerSanjana2021_K562_2                      Liscovitch-BrauerSanjana2021
# McFarlandTsherniak2020                                         McFarlandTsherniak2020
# MimitouSmibert2021                                                 MimitouSmibert2021
# NormanWeissman2019_filtered                                        NormanWeissman2019
# PapalexiSatija2021_eccite_arrayed_protein                          PapalexiSatija2021
# PapalexiSatija2021_eccite_protein                                  PapalexiSatija2021
# PierceGreenleaf2021_K562                                          PierceGreenleaf2021
# PierceGreenleaf2021_MCF7                                          PierceGreenleaf2021
# PierceGreenleaf2021_GM12878                                       PierceGreenleaf2021
# ReplogleWeissman2022_K562_essential                              ReplogleWeissman2022
# ReplogleWeissman2022_K562_gwps                                   ReplogleWeissman2022
# ReplogleWeissman2022_rpe1                                        ReplogleWeissman2022
# SchiebingerLander2019_GSE106340                                 SchiebingerLander2019
# SchiebingerLander2019_GSE115943                                 SchiebingerLander2019
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...           SchraivogelSteinmetz2020
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...           SchraivogelSteinmetz2020
# ShifrutMarson2018                                                   ShifrutMarson2018
# SrivatsanTrapnell2020_sciplex2                                  SrivatsanTrapnell2020
# SrivatsanTrapnell2020_sciplex3                                  SrivatsanTrapnell2020
# SrivatsanTrapnell2020_sciplex4                                  SrivatsanTrapnell2020
# TianKampmann2019_day7neuron                                          TianKampmann2019
# TianKampmann2019_iPSC                                                TianKampmann2019
# TianKampmann2021_CRISPRa                                             TianKampmann2021
# TianKampmann2021_CRISPRi                                             TianKampmann2021
# WeinrebKlein2020                                                     WeinrebKlein2020
# XieHon2017                                                                 XieHon2017
# ZhaoSims2021                                                             ZhaoSims2021
#
#                                                                        dataset_index  \
# AdamsonWeissman2016_GSM2406675_10X001                              GSM2406675_10X001
# AdamsonWeissman2016_GSM2406677_10X005                              GSM2406677_10X005
# AdamsonWeissman2016_GSM2406681_10X010                              GSM2406681_10X010
# AissaBenevolenskaya2021
# ChangYe2021
# DatlingerBock2017
# DatlingerBock2021
# DixitRegev2016
# FrangiehIzar2021_protein                                                     protein
# GasperiniShendure2019_atscale                                                atscale
# GasperiniShendure2019_highMOI                                                highMOI
# GasperiniShendure2019_lowMOI                                                  lowMOI
# GehringPachter2019
# Liscovitch-BrauerSanjana2021_K562_1                                           K562_1
# Liscovitch-BrauerSanjana2021_K562_2                                           K562_2
# McFarlandTsherniak2020
# MimitouSmibert2021
# NormanWeissman2019_filtered                                                 filtered
# PapalexiSatija2021_eccite_arrayed_protein                     eccite_arrayed_protein
# PapalexiSatija2021_eccite_protein                                     eccite_protein
# PierceGreenleaf2021_K562                                                        K562
# PierceGreenleaf2021_MCF7                                                        MCF7
# PierceGreenleaf2021_GM12878                                                  GM12878
# ReplogleWeissman2022_K562_essential                                   K562_essential
# ReplogleWeissman2022_K562_gwps                                             K562_gwps
# ReplogleWeissman2022_rpe1                                                       rpe1
# SchiebingerLander2019_GSE106340                                            GSE106340
# SchiebingerLander2019_GSE115943                                            GSE115943
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  TAP_SCREEN__chromosome_11_screen
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...   TAP_SCREEN__chromosome_8_screen
# ShifrutMarson2018
# SrivatsanTrapnell2020_sciplex2                                              sciplex2
# SrivatsanTrapnell2020_sciplex3                                              sciplex3
# SrivatsanTrapnell2020_sciplex4                                              sciplex4
# TianKampmann2019_day7neuron                                               day7neuron
# TianKampmann2019_iPSC                                                           iPSC
# TianKampmann2021_CRISPRa                                                     CRISPRa
# TianKampmann2021_CRISPRi                                                     CRISPRi
# WeinrebKlein2020
# XieHon2017
# ZhaoSims2021
#
#                                                                                                 Title  \
# AdamsonWeissman2016_GSM2406675_10X001               A multiplexed single-cell CRISPR screening pla...
# AdamsonWeissman2016_GSM2406677_10X005               A multiplexed single-cell CRISPR screening pla...
# AdamsonWeissman2016_GSM2406681_10X010               A multiplexed single-cell CRISPR screening pla...
# AissaBenevolenskaya2021                             Single-cell transcriptional changes associated...
# ChangYe2021                                         Identifying transcriptional programs underlyin...
# DatlingerBock2017                                   Pooled CRISPR screening with single-cell trans...
# DatlingerBock2021                                   Ultra-high-throughput single-cell RNA sequenci...
# DixitRegev2016                                      Perturb-Seq: Dissecting Molecular Circuits wit...
# FrangiehIzar2021_protein                            Multimodal pooled Perturb-CITE-seq screens in ...
# GasperiniShendure2019_atscale                       A Genome-wide Framework for Mapping Gene Regul...
# GasperiniShendure2019_highMOI                       A Genome-wide Framework for Mapping Gene Regul...
# GasperiniShendure2019_lowMOI                        A Genome-wide Framework for Mapping Gene Regul...
# GehringPachter2019                                  Highly multiplexed single-cell RNA-seq by DNA ...
# Liscovitch-BrauerSanjana2021_K562_1                 Profiling the genetic determinants of chromati...
# Liscovitch-BrauerSanjana2021_K562_2                 Profiling the genetic determinants of chromati...
# McFarlandTsherniak2020                              Multiplexed single-cell transcriptional respon...
# MimitouSmibert2021                                  Scalable, multimodal profiling of chromatin ac...
# NormanWeissman2019_filtered                         Exploring genetic interaction manifolds constr...
# PapalexiSatija2021_eccite_arrayed_protein           Characterizing the molecular regulation of inh...
# PapalexiSatija2021_eccite_protein                   Characterizing the molecular regulation of inh...
# PierceGreenleaf2021_K562                            High-throughput single-cell chromatin accessib...
# PierceGreenleaf2021_MCF7                            High-throughput single-cell chromatin accessib...
# PierceGreenleaf2021_GM12878                         High-throughput single-cell chromatin accessib...
# ReplogleWeissman2022_K562_essential                 Mapping information-rich genotype-phenotype la...
# ReplogleWeissman2022_K562_gwps                      Mapping information-rich genotype-phenotype la...
# ReplogleWeissman2022_rpe1                           Mapping information-rich genotype-phenotype la...
# SchiebingerLander2019_GSE106340                     Optimal-Transport Analysis of Single-Cell Gene...
# SchiebingerLander2019_GSE115943                     Optimal-Transport Analysis of Single-Cell Gene...
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  Targeted Perturb-seq enables genome-scale gene...
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  Targeted Perturb-seq enables genome-scale gene...
# ShifrutMarson2018                                   Genome-wide CRISPR Screens in Primary Human T ...
# SrivatsanTrapnell2020_sciplex2                      Massively multiplex chemical transcriptomics a...
# SrivatsanTrapnell2020_sciplex3                      Massively multiplex chemical transcriptomics a...
# SrivatsanTrapnell2020_sciplex4                      Massively multiplex chemical transcriptomics a...
# TianKampmann2019_day7neuron                         CRISPR Interference-Based Platform for Multimo...
# TianKampmann2019_iPSC                               CRISPR Interference-Based Platform for Multimo...
# TianKampmann2021_CRISPRa                            Genome-wide CRISPRi/a screens in human neurons...
# TianKampmann2021_CRISPRi                            Genome-wide CRISPRi/a screens in human neurons...
# WeinrebKlein2020                                    Lineage tracing on transcriptional landscapes ...
# XieHon2017                                          Multiplexed engineering and analysis of endoge...
# ZhaoSims2021                                        Deconvolution of Cell Type-Specific Drug Respo...
#
#                                                                                          doi/url  \
# AdamsonWeissman2016_GSM2406675_10X001                 https://doi.org/10.1016/j.cell.2016.11.048
# AdamsonWeissman2016_GSM2406677_10X005                 https://doi.org/10.1016/j.cell.2016.11.048
# AdamsonWeissman2016_GSM2406681_10X010                 https://doi.org/10.1016/j.cell.2016.11.048
# AissaBenevolenskaya2021                               https://doi.org/10.1038/s41467-021-21884-z
# ChangYe2021                                           https://doi.org/10.1038/s41587-021-01005-3
# DatlingerBock2017                                             https://doi.org/10.1038/nmeth.4177
# DatlingerBock2021                                     https://doi.org/10.1038/s41592-021-01153-z
# DixitRegev2016                                        https://doi.org/10.1016/j.cell.2016.11.038
# FrangiehIzar2021_protein                              https://doi.org/10.1038/s41588-021-00779-1
# GasperiniShendure2019_atscale                         https://doi.org/10.1016/j.cell.2018.11.029
# GasperiniShendure2019_highMOI                         https://doi.org/10.1016/j.cell.2018.11.029
# GasperiniShendure2019_lowMOI                          https://doi.org/10.1016/j.cell.2018.11.029
# GehringPachter2019                                     https://doi.org/10.1038/s41587-019-0372-z
# Liscovitch-BrauerSanjana2021_K562_1                   https://doi.org/10.1038/s41587-021-00902-x
# Liscovitch-BrauerSanjana2021_K562_2                   https://doi.org/10.1038/s41587-021-00902-x
# McFarlandTsherniak2020                                https://doi.org/10.1038/s41467-020-17440-w
# MimitouSmibert2021                                    https://doi.org/10.1038/s41587-021-00927-2
# NormanWeissman2019_filtered                              https://doi.org/10.1126/science.aax4438
# PapalexiSatija2021_eccite_arrayed_protein             https://doi.org/10.1038/s41588-021-00778-2
# PapalexiSatija2021_eccite_protein                     https://doi.org/10.1038/s41588-021-00778-2
# PierceGreenleaf2021_K562                              https://doi.org/10.1038/s41467-021-23213-w
# PierceGreenleaf2021_MCF7                              https://doi.org/10.1038/s41467-021-23213-w
# PierceGreenleaf2021_GM12878                           https://doi.org/10.1038/s41467-021-23213-w
# ReplogleWeissman2022_K562_essential                   https://doi.org/10.1016/j.cell.2022.05.013
# ReplogleWeissman2022_K562_gwps                        https://doi.org/10.1016/j.cell.2022.05.013
# ReplogleWeissman2022_rpe1                             https://doi.org/10.1016/j.cell.2022.05.013
# SchiebingerLander2019_GSE106340                       https://doi.org/10.1016/j.cell.2019.01.006
# SchiebingerLander2019_GSE115943                       https://doi.org/10.1016/j.cell.2019.01.006
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...     https://doi.org/10.1038/s41592-020-0837-5
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...     https://doi.org/10.1038/s41592-020-0837-5
# ShifrutMarson2018                                     https://doi.org/10.1016/j.cell.2018.10.024
# SrivatsanTrapnell2020_sciplex2                           https://doi.org/10.1126/science.aax6234
# SrivatsanTrapnell2020_sciplex3                           https://doi.org/10.1126/science.aax6234
# SrivatsanTrapnell2020_sciplex4                           https://doi.org/10.1126/science.aax6234
# TianKampmann2019_day7neuron                         https://doi.org/10.1016/j.neuron.2019.07.014
# TianKampmann2019_iPSC                               https://doi.org/10.1016/j.neuron.2019.07.014
# TianKampmann2021_CRISPRa                              https://doi.org/10.1038/s41593-021-00862-0
# TianKampmann2021_CRISPRi                              https://doi.org/10.1038/s41593-021-00862-0
# WeinrebKlein2020                                         https://doi.org/10.1126/science.aaw3381
# XieHon2017                                          https://doi.org/10.1016/j.molcel.2017.03.007
# ZhaoSims2021                                           https://doi.org/10.1101/2020.04.22.056341
#
#                                                              First Author  \
# AdamsonWeissman2016_GSM2406675_10X001                       Britt Adamson
# AdamsonWeissman2016_GSM2406677_10X005                       Britt Adamson
# AdamsonWeissman2016_GSM2406681_10X010                       Britt Adamson
# AissaBenevolenskaya2021                                   Alexandre Aissa
# ChangYe2021                                                 Matthew Chang
# DatlingerBock2017                                          Paul Datlinger
# DatlingerBock2021                                          Paul Datlinger
# DixitRegev2016                                                Atray Dixit
# FrangiehIzar2021_protein                                   Chris Frangieh
# GasperiniShendure2019_atscale                             Molly Gasperini
# GasperiniShendure2019_highMOI                             Molly Gasperini
# GasperiniShendure2019_lowMOI                              Molly Gasperini
# GehringPachter2019                                           Jase Gehring
# Liscovitch-BrauerSanjana2021_K562_1                 Liscovitch-Brauer, N.
# Liscovitch-BrauerSanjana2021_K562_2                 Liscovitch-Brauer, N.
# McFarlandTsherniak2020                                    James McFarland
# MimitouSmibert2021                                       Eleni P. Mimitou
# NormanWeissman2019_filtered                                 Thomas Norman
# PapalexiSatija2021_eccite_arrayed_protein                    Papalexi, E.
# PapalexiSatija2021_eccite_protein                            Papalexi, E.
# PierceGreenleaf2021_K562                                     Sarah Pierce
# PierceGreenleaf2021_MCF7                                     Sarah Pierce
# PierceGreenleaf2021_GM12878                                  Sarah Pierce
# ReplogleWeissman2022_K562_essential                       Joseph Replogle
# ReplogleWeissman2022_K562_gwps                            Joseph Replogle
# ReplogleWeissman2022_rpe1                                 Joseph Replogle
# SchiebingerLander2019_GSE106340                      Geoffrey Schiebinger
# SchiebingerLander2019_GSE115943                      Geoffrey Schiebinger
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...     Daniel Schraivogel
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...     Daniel Schraivogel
# ShifrutMarson2018                                            Eric Shifrut
# SrivatsanTrapnell2020_sciplex2                           Sanjay Srivatsan
# SrivatsanTrapnell2020_sciplex3                           Sanjay Srivatsan
# SrivatsanTrapnell2020_sciplex4                           Sanjay Srivatsan
# TianKampmann2019_day7neuron                                   Ruilin Tian
# TianKampmann2019_iPSC                                         Ruilin Tian
# TianKampmann2021_CRISPRa                                      Ruilin Tian
# TianKampmann2021_CRISPRi                                      Ruilin Tian
# WeinrebKlein2020                                            Caleb Weinreb
# XieHon2017                                                      Shiqi Xie
# ZhaoSims2021                                                 Wenting Zhao
#
#                                                                      Organisms  \
# AdamsonWeissman2016_GSM2406675_10X001                             Homo sapiens
# AdamsonWeissman2016_GSM2406677_10X005                             Homo sapiens
# AdamsonWeissman2016_GSM2406681_10X010                             Homo sapiens
# AissaBenevolenskaya2021                             Homo sapiens; Mus musculus
# ChangYe2021                                                       Homo sapiens
# DatlingerBock2017                                   Homo sapiens; Mus musculus
# DatlingerBock2021                                                 Homo sapiens
# DixitRegev2016                                      Homo sapiens; Mus musculus
# FrangiehIzar2021_protein                                          Homo sapiens
# GasperiniShendure2019_atscale                                     Homo sapiens
# GasperiniShendure2019_highMOI                                     Homo sapiens
# GasperiniShendure2019_lowMOI                                      Homo sapiens
# GehringPachter2019                                                Mus musculus
# Liscovitch-BrauerSanjana2021_K562_1                               Homo sapiens
# Liscovitch-BrauerSanjana2021_K562_2                               Homo sapiens
# McFarlandTsherniak2020                                            Homo sapiens
# MimitouSmibert2021                                                Homo sapiens
# NormanWeissman2019_filtered                                       Homo sapiens
# PapalexiSatija2021_eccite_arrayed_protein                   Homo sapiens THP-1
# PapalexiSatija2021_eccite_protein                           Homo sapiens THP-1
# PierceGreenleaf2021_K562                                          Homo sapiens
# PierceGreenleaf2021_MCF7                                          Homo sapiens
# PierceGreenleaf2021_GM12878                                       Homo sapiens
# ReplogleWeissman2022_K562_essential                               Homo sapiens
# ReplogleWeissman2022_K562_gwps                                    Homo sapiens
# ReplogleWeissman2022_rpe1                                         Homo sapiens
# SchiebingerLander2019_GSE106340                                   Mus musculus
# SchiebingerLander2019_GSE115943                                   Mus musculus
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  Homo sapiens; Mus musculus
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  Homo sapiens; Mus musculus
# ShifrutMarson2018                                                 Homo sapiens
# SrivatsanTrapnell2020_sciplex2                      Homo sapiens; Mus musculus
# SrivatsanTrapnell2020_sciplex3                      Homo sapiens; Mus musculus
# SrivatsanTrapnell2020_sciplex4                      Homo sapiens; Mus musculus
# TianKampmann2019_day7neuron                                       Homo sapiens
# TianKampmann2019_iPSC                                             Homo sapiens
# TianKampmann2021_CRISPRa                                          Homo sapiens
# TianKampmann2021_CRISPRi                                          Homo sapiens
# WeinrebKlein2020                                                  Mus musculus
# XieHon2017                                          Homo sapiens; Mus musculus
# ZhaoSims2021                                                      Homo sapiens
#
#                                                    Modality = Data type  \
# AdamsonWeissman2016_GSM2406675_10X001                               RNA
# AdamsonWeissman2016_GSM2406677_10X005                               RNA
# AdamsonWeissman2016_GSM2406681_10X010                               RNA
# AissaBenevolenskaya2021                                             RNA
# ChangYe2021                                                         RNA
# DatlingerBock2017                                                   RNA
# DatlingerBock2021                                                   RNA
# DixitRegev2016                                                      RNA
# FrangiehIzar2021_protein                                  RNA + protein
# GasperiniShendure2019_atscale                                       RNA
# GasperiniShendure2019_highMOI                                       RNA
# GasperiniShendure2019_lowMOI                                        RNA
# GehringPachter2019                                                  RNA
# Liscovitch-BrauerSanjana2021_K562_1                                ATAC
# Liscovitch-BrauerSanjana2021_K562_2                                ATAC
# McFarlandTsherniak2020                                              RNA
# MimitouSmibert2021                                       ATAC + protein
# NormanWeissman2019_filtered                                         RNA
# PapalexiSatija2021_eccite_arrayed_protein                 RNA + protein
# PapalexiSatija2021_eccite_protein                         RNA + protein
# PierceGreenleaf2021_K562                                           ATAC
# PierceGreenleaf2021_MCF7                                           ATAC
# PierceGreenleaf2021_GM12878                                        ATAC
# ReplogleWeissman2022_K562_essential                                 RNA
# ReplogleWeissman2022_K562_gwps                                      RNA
# ReplogleWeissman2022_rpe1                                           RNA
# SchiebingerLander2019_GSE106340                                     RNA
# SchiebingerLander2019_GSE115943                                     RNA
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                  RNA
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                  RNA
# ShifrutMarson2018                                                   RNA
# SrivatsanTrapnell2020_sciplex2                                      RNA
# SrivatsanTrapnell2020_sciplex3                                      RNA
# SrivatsanTrapnell2020_sciplex4                                      RNA
# TianKampmann2019_day7neuron                                         RNA
# TianKampmann2019_iPSC                                               RNA
# TianKampmann2021_CRISPRa                                            RNA
# TianKampmann2021_CRISPRi                                            RNA
# WeinrebKlein2020                                                    RNA
# XieHon2017                                                          RNA
# ZhaoSims2021                                                        RNA
#
#                                                                                    Method  \
# AdamsonWeissman2016_GSM2406675_10X001                                         Perturb-seq
# AdamsonWeissman2016_GSM2406677_10X005                                         Perturb-seq
# AdamsonWeissman2016_GSM2406681_10X010                                         Perturb-seq
# AissaBenevolenskaya2021                                                          Drop-Seq
# ChangYe2021                                                    clonal tagging (TraCe-seq)
# DatlingerBock2017                                                                CROP-seq
# DatlingerBock2021                                   scifi-RNA-seq (derived from CROP-seq)
# DixitRegev2016                                                                Perturb-seq
# FrangiehIzar2021_protein                                                 Perturb-CITE-seq
# GasperiniShendure2019_atscale                                                    CROP-seq
# GasperiniShendure2019_highMOI                                                    CROP-seq
# GasperiniShendure2019_lowMOI                                                     CROP-seq
# GehringPachter2019                                      96-plex scRNA-seq\noligo barcodes
# Liscovitch-BrauerSanjana2021_K562_1                                        CRISPR–sciATAC
# Liscovitch-BrauerSanjana2021_K562_2                                        CRISPR–sciATAC
# McFarlandTsherniak2020                                         MIX-seq (pooled scRNA-seq)
# MimitouSmibert2021                                                               ASAP-seq
# NormanWeissman2019_filtered                                                   Perturb-seq
# PapalexiSatija2021_eccite_arrayed_protein                                      ECCITE-seq
# PapalexiSatija2021_eccite_protein                                              ECCITE-seq
# PierceGreenleaf2021_K562                                                       Spear-ATAC
# PierceGreenleaf2021_MCF7                                                       Spear-ATAC
# PierceGreenleaf2021_GM12878                                                    Spear-ATAC
# ReplogleWeissman2022_K562_essential                                           Perturb-seq
# ReplogleWeissman2022_K562_gwps                                                Perturb-seq
# ReplogleWeissman2022_rpe1                                                     Perturb-seq
# SchiebingerLander2019_GSE106340                                           plain scRNA-seq
# SchiebingerLander2019_GSE115943                                           plain scRNA-seq
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                TAP-seq
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                TAP-seq
# ShifrutMarson2018                                                                CROP-seq
# SrivatsanTrapnell2020_sciplex2                                 sci-Plex (nuclear hashing)
# SrivatsanTrapnell2020_sciplex3                                 sci-Plex (nuclear hashing)
# SrivatsanTrapnell2020_sciplex4                                 sci-Plex (nuclear hashing)
# TianKampmann2019_day7neuron                                                      CROP-seq
# TianKampmann2019_iPSC                                                            CROP-seq
# TianKampmann2021_CRISPRa                                                         CROP-seq
# TianKampmann2021_CRISPRi                                                         CROP-seq
# WeinrebKlein2020                                                   clonal tagging (LARRY)
# XieHon2017                                                                     Mosaic-seq
# ZhaoSims2021                                                                    scRNA-seq
#
#                                                                                               Tissues  \
# AdamsonWeissman2016_GSM2406675_10X001                                                            K562
# AdamsonWeissman2016_GSM2406677_10X005                                                            K562
# AdamsonWeissman2016_GSM2406681_10X010                                                            K562
# AissaBenevolenskaya2021                                  cell lines, patient tissue, mouse xenografts
# ChangYe2021                                         lung and breast cancer cell lines PC9, MCF-10A...
# DatlingerBock2017                                                          Jurkat cells (immunecells)
# DatlingerBock2021                                   four human cell lines (HEK293T, Jurkat, K562, ...
# DixitRegev2016                                                                             BMDC, K562
# FrangiehIzar2021_protein                                              co-culture of melanoma and TILs
# GasperiniShendure2019_atscale                                                                    K562
# GasperiniShendure2019_highMOI                                                                    K562
# GasperiniShendure2019_lowMOI                                                                     K562
# GehringPachter2019                                  mouse neural stem cells (human only for specie...
# Liscovitch-BrauerSanjana2021_K562_1                                                  Myeloid Leukemia
# Liscovitch-BrauerSanjana2021_K562_2                                                  Myeloid Leukemia
# McFarlandTsherniak2020                                                                            NaN
# MimitouSmibert2021                                                               Purified CD4 T cells
# NormanWeissman2019_filtered                                                                      K562
# PapalexiSatija2021_eccite_arrayed_protein                                 THP-1 (monocytic leukemia )
# PapalexiSatija2021_eccite_protein                                         THP-1 (monocytic leukemia )
# PierceGreenleaf2021_K562                                                              K562 (leukemia)
# PierceGreenleaf2021_MCF7                                                         MCF7 (breast cancer)
# PierceGreenleaf2021_GM12878                                            GM12878 (lymphoblastoid cells)
# ReplogleWeissman2022_K562_essential                                                               NaN
# ReplogleWeissman2022_K562_gwps                                                                    NaN
# ReplogleWeissman2022_rpe1                                                                         NaN
# SchiebingerLander2019_GSE106340                                                                 iPSCs
# SchiebingerLander2019_GSE115943                                                                 iPSCs
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                   K562, BMDC, lung
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                   K562, BMDC, lung
# ShifrutMarson2018                                                               Primary Human T Cells
# SrivatsanTrapnell2020_sciplex2                      A549 (lung adenocarcinoma), K562 (chronic myel...
# SrivatsanTrapnell2020_sciplex3                      A549 (lung adenocarcinoma), K562 (chronic myel...
# SrivatsanTrapnell2020_sciplex4                      A549 (lung adenocarcinoma), K562 (chronic myel...
# TianKampmann2019_day7neuron                                                      iPSC derived neurons
# TianKampmann2019_iPSC                                                            iPSC derived neurons
# TianKampmann2021_CRISPRa                                                   human iPSC-derived neurons
# TianKampmann2021_CRISPRi                                                   human iPSC-derived neurons
# WeinrebKlein2020                                                    hematopoiesis / mouse bone marrow
# XieHon2017                                                                   K562 and 293T cell lines
# ZhaoSims2021                                                             glioblastoma, patient tissue
#
#                                                    Number of perturbations (incl. unperturbed)  \
# AdamsonWeissman2016_GSM2406675_10X001                                                       10
# AdamsonWeissman2016_GSM2406677_10X005                                                       21
# AdamsonWeissman2016_GSM2406681_10X010                                                      115
# AissaBenevolenskaya2021                                                                      4
# ChangYe2021                                                                                  4
# DatlingerBock2017                                                                           97
# DatlingerBock2021                                                                           48
# DixitRegev2016                                                                              31
# FrangiehIzar2021_protein                                                                   249
# GasperiniShendure2019_atscale                                    43314 (includes combinations)
# GasperiniShendure2019_highMOI                                    39087 (includes combinations)
# GasperiniShendure2019_lowMOI                                     16531 (includes combinations)
# GehringPachter2019                                                                           4
# Liscovitch-BrauerSanjana2021_K562_1                                                         22
# Liscovitch-BrauerSanjana2021_K562_2                                                         84
# McFarlandTsherniak2020                                                                      18
# MimitouSmibert2021                                                                           5
# NormanWeissman2019_filtered                                                                237
# PapalexiSatija2021_eccite_arrayed_protein                                                   11
# PapalexiSatija2021_eccite_protein                                                           99
# PierceGreenleaf2021_K562                                                                    41
# PierceGreenleaf2021_MCF7                                                                    41
# PierceGreenleaf2021_GM12878                                                                 41
# ReplogleWeissman2022_K562_essential                                                       2058
# ReplogleWeissman2022_K562_gwps                                                            9867
# ReplogleWeissman2022_rpe1                                                                 2394
# SchiebingerLander2019_GSE106340                                                              3
# SchiebingerLander2019_GSE115943                                                              3
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                        3105
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                        4115
# ShifrutMarson2018                                                                           49
# SrivatsanTrapnell2020_sciplex2                                                               5
# SrivatsanTrapnell2020_sciplex3                                                             190
# SrivatsanTrapnell2020_sciplex4                                                               9
# TianKampmann2019_day7neuron                                                                 27
# TianKampmann2019_iPSC                                                                       27
# TianKampmann2021_CRISPRa                                                                   101
# TianKampmann2021_CRISPRi                                                                   185
# WeinrebKlein2020                                                                             5
# XieHon2017                                                                                  37
# ZhaoSims2021                                                                                 7
#
#                                                     ...  \
# AdamsonWeissman2016_GSM2406675_10X001               ...
# AdamsonWeissman2016_GSM2406677_10X005               ...
# AdamsonWeissman2016_GSM2406681_10X010               ...
# AissaBenevolenskaya2021                             ...
# ChangYe2021                                         ...
# DatlingerBock2017                                   ...
# DatlingerBock2021                                   ...
# DixitRegev2016                                      ...
# FrangiehIzar2021_protein                            ...
# GasperiniShendure2019_atscale                       ...
# GasperiniShendure2019_highMOI                       ...
# GasperiniShendure2019_lowMOI                        ...
# GehringPachter2019                                  ...
# Liscovitch-BrauerSanjana2021_K562_1                 ...
# Liscovitch-BrauerSanjana2021_K562_2                 ...
# McFarlandTsherniak2020                              ...
# MimitouSmibert2021                                  ...
# NormanWeissman2019_filtered                         ...
# PapalexiSatija2021_eccite_arrayed_protein           ...
# PapalexiSatija2021_eccite_protein                   ...
# PierceGreenleaf2021_K562                            ...
# PierceGreenleaf2021_MCF7                            ...
# PierceGreenleaf2021_GM12878                         ...
# ReplogleWeissman2022_K562_essential                 ...
# ReplogleWeissman2022_K562_gwps                      ...
# ReplogleWeissman2022_rpe1                           ...
# SchiebingerLander2019_GSE106340                     ...
# SchiebingerLander2019_GSE115943                     ...
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  ...
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  ...
# ShifrutMarson2018                                   ...
# SrivatsanTrapnell2020_sciplex2                      ...
# SrivatsanTrapnell2020_sciplex3                      ...
# SrivatsanTrapnell2020_sciplex4                      ...
# TianKampmann2019_day7neuron                         ...
# TianKampmann2019_iPSC                               ...
# TianKampmann2021_CRISPRa                            ...
# TianKampmann2021_CRISPRi                            ...
# WeinrebKlein2020                                    ...
# XieHon2017                                          ...
# ZhaoSims2021                                        ...
#
#                                                                          disease  \
# AdamsonWeissman2016_GSM2406675_10X001               chronic myelogenous leukemia
# AdamsonWeissman2016_GSM2406677_10X005               chronic myelogenous leukemia
# AdamsonWeissman2016_GSM2406681_10X010               chronic myelogenous leukemia
# AissaBenevolenskaya2021                                                      NaN
# ChangYe2021                                                  lung adenocarcinoma
# DatlingerBock2017                                          acute T cell leukemia
# DatlingerBock2021                                          acute T cell leukemia
# DixitRegev2016                                              myelogenous leukemia
# FrangiehIzar2021_protein                                                melanoma
# GasperiniShendure2019_atscale                       chronic myelogenous leukemia
# GasperiniShendure2019_highMOI                       chronic myelogenous leukemia
# GasperiniShendure2019_lowMOI                        chronic myelogenous leukemia
# GehringPachter2019                                                       healthy
# Liscovitch-BrauerSanjana2021_K562_1                         myelogenous leukemia
# Liscovitch-BrauerSanjana2021_K562_2                         myelogenous leukemia
# McFarlandTsherniak2020                                               lung cancer
# MimitouSmibert2021                                                       healthy
# NormanWeissman2019_filtered                         chronic myelogenous leukemia
# PapalexiSatija2021_eccite_arrayed_protein               acute monocytic leukemia
# PapalexiSatija2021_eccite_protein                       acute monocytic leukemia
# PierceGreenleaf2021_K562                                                 healthy
# PierceGreenleaf2021_MCF7                                    myelogenous leukemia
# PierceGreenleaf2021_GM12878                                       adenocarcinoma
# ReplogleWeissman2022_K562_essential                     chronic myeloid leukemia
# ReplogleWeissman2022_K562_gwps                          chronic myeloid leukemia
# ReplogleWeissman2022_rpe1                               chronic myeloid leukemia
# SchiebingerLander2019_GSE106340                                          healthy
# SchiebingerLander2019_GSE115943                                          healthy
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  chronic myelogenous leukemia
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  chronic myelogenous leukemia
# ShifrutMarson2018                                                        healthy
# SrivatsanTrapnell2020_sciplex2                               lung adenocarcinoma
# SrivatsanTrapnell2020_sciplex3                             breast adenocarcinoma
# SrivatsanTrapnell2020_sciplex4                               lung adenocarcinoma
# TianKampmann2019_day7neuron                                              healthy
# TianKampmann2019_iPSC                                                    healthy
# TianKampmann2021_CRISPRa                                                 healthy
# TianKampmann2021_CRISPRi                                                 healthy
# WeinrebKlein2020                                                         healthy
# XieHon2017                                              chronic myeloid leukemia
# ZhaoSims2021                                                        glioblastoma
#
#                                                                            celltype  \
# AdamsonWeissman2016_GSM2406675_10X001                                  lymphoblasts
# AdamsonWeissman2016_GSM2406677_10X005                                  lymphoblasts
# AdamsonWeissman2016_GSM2406681_10X010                                  lymphoblasts
# AissaBenevolenskaya2021                                                         NaN
# ChangYe2021                                                                     NaN
# DatlingerBock2017                                                           T cells
# DatlingerBock2021                                                           T cells
# DixitRegev2016                                                         lymphoblasts
# FrangiehIzar2021_protein                                                melanocytes
# GasperiniShendure2019_atscale                                          lymphoblasts
# GasperiniShendure2019_highMOI                                          lymphoblasts
# GasperiniShendure2019_lowMOI                                           lymphoblasts
# GehringPachter2019                                                neural stem cells
# Liscovitch-BrauerSanjana2021_K562_1                                    lymphoblasts
# Liscovitch-BrauerSanjana2021_K562_2                                    lymphoblasts
# McFarlandTsherniak2020                                                          NaN
# MimitouSmibert2021                                                              NaN
# NormanWeissman2019_filtered                                            lymphoblasts
# PapalexiSatija2021_eccite_arrayed_protein                                 monocytes
# PapalexiSatija2021_eccite_protein                                         monocytes
# PierceGreenleaf2021_K562                                                        NaN
# PierceGreenleaf2021_MCF7                                               lymphoblasts
# PierceGreenleaf2021_GM12878                                                     NaN
# ReplogleWeissman2022_K562_essential                                    lymphoblasts
# ReplogleWeissman2022_K562_gwps                                         lymphoblasts
# ReplogleWeissman2022_rpe1                                                epithelial
# SchiebingerLander2019_GSE106340                                               mESCs
# SchiebingerLander2019_GSE115943                                               mESCs
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                     lymphoblasts
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                     lymphoblasts
# ShifrutMarson2018                                                           T cells
# SrivatsanTrapnell2020_sciplex2                      alveolar basal epithelial cells
# SrivatsanTrapnell2020_sciplex3                             mammary epithelial cells
# SrivatsanTrapnell2020_sciplex4                      alveolar basal epithelial cells
# TianKampmann2019_day7neuron                                     iPSC-induced neuron
# TianKampmann2019_iPSC                                                          iPSC
# TianKampmann2021_CRISPRa                                        iPSC-induced neuron
# TianKampmann2021_CRISPRi                                        iPSC-induced neuron
# WeinrebKlein2020                                                   Undifferentiated
# XieHon2017                                                             lymphoblasts
# ZhaoSims2021                                                                unknown
#
# ...
# SrivatsanTrapnell2020_sciplex4                                                                n
# TianKampmann2019_day7neuron                                                                   y
# TianKampmann2019_iPSC                                                                         y
# TianKampmann2021_CRISPRa                                                                      n
# TianKampmann2021_CRISPRi                                                                      n
# WeinrebKlein2020                                                                              y
# XieHon2017                                                                                    n
# ZhaoSims2021                                                                                  n
#
#                                                                      multiple concentrations?  \
# AdamsonWeissman2016_GSM2406675_10X001                                                       n
# AdamsonWeissman2016_GSM2406677_10X005                                                       n
# AdamsonWeissman2016_GSM2406681_10X010                                                       n
# AissaBenevolenskaya2021                                                                     n
# ChangYe2021                                                                                 n
# DatlingerBock2017                                                                           n
# DatlingerBock2021                                                                           n
# DixitRegev2016                                      partially (different MOIs for one screen)
# FrangiehIzar2021_protein                                                                    n
# GasperiniShendure2019_atscale                                                               n
# GasperiniShendure2019_highMOI                                                               n
# GasperiniShendure2019_lowMOI                                                                n
# GehringPachter2019                                                                          y
# Liscovitch-BrauerSanjana2021_K562_1                                                       NaN
# Liscovitch-BrauerSanjana2021_K562_2                                                       NaN
# McFarlandTsherniak2020                                                                      n
# MimitouSmibert2021                                                                        NaN
# NormanWeissman2019_filtered                                                                 n
# PapalexiSatija2021_eccite_arrayed_protein                                                   n
# PapalexiSatija2021_eccite_protein                                                           n
# PierceGreenleaf2021_K562                                                                    n
# PierceGreenleaf2021_MCF7                                                                    n
# PierceGreenleaf2021_GM12878                                                                 n
# ReplogleWeissman2022_K562_essential                                                         n
# ReplogleWeissman2022_K562_gwps                                                              n
# ReplogleWeissman2022_rpe1                                                                   n
# SchiebingerLander2019_GSE106340                                                             n
# SchiebingerLander2019_GSE115943                                                             n
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                          n
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...                                          n
# ShifrutMarson2018                                                                           n
# SrivatsanTrapnell2020_sciplex2                                                              y
# SrivatsanTrapnell2020_sciplex3                                                              y
# SrivatsanTrapnell2020_sciplex4                                                              y
# TianKampmann2019_day7neuron                                                                 n
# TianKampmann2019_iPSC                                                                       n
# TianKampmann2021_CRISPRa                                                                    n
# TianKampmann2021_CRISPRi                                                                    n
# WeinrebKlein2020                                                                            n
# XieHon2017                                                                                  n
# ZhaoSims2021                                                                                n
#
#                                                    combined perturbations?  \
# AdamsonWeissman2016_GSM2406675_10X001                                    y
# AdamsonWeissman2016_GSM2406677_10X005                                    y
# AdamsonWeissman2016_GSM2406681_10X010                                    y
# AissaBenevolenskaya2021                                          partially
# ChangYe2021                                                              n
# DatlingerBock2017                                                        y
# DatlingerBock2021                                                        y
# DixitRegev2016                                                           y
# FrangiehIzar2021_protein                                                 n
# GasperiniShendure2019_atscale                                            y
# GasperiniShendure2019_highMOI                                            y
# GasperiniShendure2019_lowMOI                                             y
# GehringPachter2019                                                       y
# Liscovitch-BrauerSanjana2021_K562_1                                      n
# Liscovitch-BrauerSanjana2021_K562_2                                      n
# McFarlandTsherniak2020                                                   n
# MimitouSmibert2021                                                       n
# NormanWeissman2019_filtered                                              y
# PapalexiSatija2021_eccite_arrayed_protein                                n
# PapalexiSatija2021_eccite_protein                                        n
# PierceGreenleaf2021_K562                                                 y
# PierceGreenleaf2021_MCF7                                                 y
# PierceGreenleaf2021_GM12878                                              y
# ReplogleWeissman2022_K562_essential                                      n
# ReplogleWeissman2022_K562_gwps                                           n
# ReplogleWeissman2022_rpe1                                                n
# SchiebingerLander2019_GSE106340                                          n
# SchiebingerLander2019_GSE115943                                          n
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...      partially (CRISPR)
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...      partially (CRISPR)
# ShifrutMarson2018                                                        y
# SrivatsanTrapnell2020_sciplex2                                           n
# SrivatsanTrapnell2020_sciplex3                                           n
# SrivatsanTrapnell2020_sciplex4                                           n
# TianKampmann2019_day7neuron                                              y
# TianKampmann2019_iPSC                                                    y
# TianKampmann2021_CRISPRa                                                 n
# TianKampmann2021_CRISPRi                                                 n
# WeinrebKlein2020                                                         n
# XieHon2017                                              partially (CRISPR)
# ZhaoSims2021                                                             n
#
#                                                    Date of Submission  Year  \
# AdamsonWeissman2016_GSM2406675_10X001                      01.10.2019  2019
# AdamsonWeissman2016_GSM2406677_10X005                      01.10.2019  2019
# AdamsonWeissman2016_GSM2406681_10X010                      01.10.2019  2019
# AissaBenevolenskaya2021                                    01.11.2020  2020
# ChangYe2021                                                01.08.2021  2021
# DatlingerBock2017                                          01.12.2016  2016
# DatlingerBock2021                                          01.12.2019  2019
# DixitRegev2016                                             01.11.2016  2016
# FrangiehIzar2021_protein                                   01.08.2020  2020
# GasperiniShendure2019_atscale                              01.06.2018  2018
# GasperiniShendure2019_highMOI                              01.06.2018  2018
# GasperiniShendure2019_lowMOI                               01.06.2018  2018
# GehringPachter2019                                         01.01.2020  2020
# Liscovitch-BrauerSanjana2021_K562_1                        01.04.2021  2021
# Liscovitch-BrauerSanjana2021_K562_2                        01.04.2021  2021
# McFarlandTsherniak2020                                     01.12.2019  2019
# MimitouSmibert2021                                         01.05.2019  2019
# NormanWeissman2019_filtered                                01.03.2019  2019
# PapalexiSatija2021_eccite_arrayed_protein                  01.03.2021  2021
# PapalexiSatija2021_eccite_protein                          01.03.2021  2021
# PierceGreenleaf2021_K562                                   01.11.2020  2020
# PierceGreenleaf2021_MCF7                                   01.11.2020  2020
# PierceGreenleaf2021_GM12878                                01.11.2020  2020
# ReplogleWeissman2022_K562_essential                        10.01.2022  2022
# ReplogleWeissman2022_K562_gwps                             10.01.2022  2022
# ReplogleWeissman2022_rpe1                                  10.01.2022  2022
# SchiebingerLander2019_GSE106340                            01.02.2019  2019
# SchiebingerLander2019_GSE115943                            01.02.2019  2019
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...         01.08.2019  2019
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...         01.08.2019  2019
# ShifrutMarson2018                                          01.09.2018  2018
# SrivatsanTrapnell2020_sciplex2                             01.01.2020  2020
# SrivatsanTrapnell2020_sciplex3                             01.01.2020  2020
# SrivatsanTrapnell2020_sciplex4                             01.01.2020  2020
# TianKampmann2019_day7neuron                                01.10.2019  2019
# TianKampmann2019_iPSC                                      01.10.2019  2019
# TianKampmann2021_CRISPRa                                   01.07.2020  2020
# TianKampmann2021_CRISPRi                                   01.07.2020  2020
# WeinrebKlein2020                                           01.11.2020  2020
# XieHon2017                                                 01.03.2016  2016
# ZhaoSims2021                                               01.04.2020  2020
#
#                                                     Mini-Abstract (loosely summarized original Abstract)
# AdamsonWeissman2016_GSM2406675_10X001               Perturb-seq is applied to dissect the mammalia...
# AdamsonWeissman2016_GSM2406677_10X005               Perturb-seq is applied to dissect the mammalia...
# AdamsonWeissman2016_GSM2406681_10X010               Perturb-seq is applied to dissect the mammalia...
# AissaBenevolenskaya2021                             This study uses scRNA-seq to demonstrate the e...
# ChangYe2021                                         By conducting clonal fitness mapping and scRNA...
# DatlingerBock2017                                   This study combines pooled CRISPR screening wi...
# DatlingerBock2021                                   To enable cost-effective single-cell sequencin...
# DixitRegev2016                                      This papers introduces Perturb-seq by analyzin...
# FrangiehIzar2021_protein                            In this study, the authors developed Perturb-C...
# GasperiniShendure2019_atscale                       The authors present a multiplex, expression qu...
# GasperiniShendure2019_highMOI                       The authors present a multiplex, expression qu...
# GasperiniShendure2019_lowMOI                        The authors present a multiplex, expression qu...
# GehringPachter2019                                  This study describes a universal sample multip...
# Liscovitch-BrauerSanjana2021_K562_1                 The authors describe a CRISPR-based, single-ce...
# Liscovitch-BrauerSanjana2021_K562_2                 The authors describe a CRISPR-based, single-ce...
# McFarlandTsherniak2020                              Here, the authors develop MIX-Seq, a method fo...
# MimitouSmibert2021                                  Here they present ATAC with select antigen pro...
# NormanWeissman2019_filtered                         Here, the authors present an analytical framew...
# PapalexiSatija2021_eccite_arrayed_protein           Here, the authors apply expanded CRISPR-compat...
# PapalexiSatija2021_eccite_protein                   Here, the authors apply expanded CRISPR-compat...
# PierceGreenleaf2021_K562                            Chromatin accessibility profiling can identify...
# PierceGreenleaf2021_MCF7                            Chromatin accessibility profiling can identify...
# PierceGreenleaf2021_GM12878                         Chromatin accessibility profiling can identify...
# ReplogleWeissman2022_K562_essential                 The authors of this study perform genome-scale...
# ReplogleWeissman2022_K562_gwps                      The authors of this study perform genome-scale...
# ReplogleWeissman2022_rpe1                           The authors of this study perform genome-scale...
# SchiebingerLander2019_GSE106340                     This study contains scRNA-seq datasets from ex...
# SchiebingerLander2019_GSE115943                     This study contains scRNA-seq datasets from ex...
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  This paper introduces targeted Perturb-seq (TA...
# SchraivogelSteinmetz2020_TAP_SCREEN__chromosome...  This paper introduces targeted Perturb-seq (TA...
# ShifrutMarson2018                                   Large-scale CRISPR screens have been challengi...
# SrivatsanTrapnell2020_sciplex2                      This study introduces “sci-Plex,” which uses “...
# SrivatsanTrapnell2020_sciplex3                      This study introduces “sci-Plex,” which uses “...
# SrivatsanTrapnell2020_sciplex4                      This study introduces “sci-Plex,” which uses “...
# TianKampmann2019_day7neuron                         Here, the authors describe a CRISPR interferen...
# TianKampmann2019_iPSC                               Here, the authors describe a CRISPR interferen...
# TianKampmann2021_CRISPRa                            Here, the authors present the first genome-wid...
# TianKampmann2021_CRISPRi                            Here, the authors present the first genome-wid...
# WeinrebKlein2020                                    The authors developed a tool called LARRY (lin...
# XieHon2017                                          Mosaic-seq is introduced as a method to system...
# ZhaoSims2021                                        This study combines multiplexed drug perturbat...
#
# [41 rows x 21 columns]

# %%
fig, ax = plt.subplots()

size = 0.3
vals = dsets['Perturbation'].value_counts()

colors_perturbation_types = {
    'CRISPRi': 'tab:blue', 
    'CRISPRa': 'tab:red', 
    'CRISPR-cas9': 'tab:orange', 
    'drugs': 'tab:green',
    'cytokines': 'tab:olive',
    'CRISPR-cas9, TCR stim': 'tab:purple'
}


#colors = colors_perturbation_types[vals.index.values]
#cmap = plt.colormaps["tab20c"]
#outer_colors = cmap(np.arange(3)*4)
#inner_colors = cmap([1, 2, 5, 6, 9, 10])

#ax.pie(dsets['Perturbation'].value_counts(), radius=1, colors=outer_colors,
#       wedgeprops=dict(width=0.3, edgecolor='w'))
ax.pie(vals, radius=1,
       wedgeprops=dict(width=1, edgecolor='w'), labels = vals.index.values,
       colors=[colors_perturbation_types[key] for key in vals.index.values],)

#ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
#       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Perturbation type')
plt.savefig("./figs/perturbation_type.png")
plt.show()

# %%
fig, ax = plt.subplots()

size = 0.3
vals = dsets['Modality = Data type'].value_counts()

#cmap = plt.colormaps["tab20c"]
#outer_colors = cmap(np.arange(3)*4)
#inner_colors = cmap([1, 2, 5, 6, 9, 10])

#ax.pie(dsets['Perturbation'].value_counts(), radius=1, colors=outer_colors,
#       wedgeprops=dict(width=0.3, edgecolor='w'))
ax.pie(vals, radius=1,# colors=outer_colors,
       wedgeprops=dict( edgecolor='w'), labels = vals.index.values)

#ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
#       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Modality')
plt.savefig("./figs/modality_pie.png")
plt.show()

# %%
dsets['tissue type'].value_counts()
# Out:
# cell_line    27
# primary       8
# stem          4
# Name: tissue type, dtype: int64

# %%
fig, ax = plt.subplots()

size = 0.3
vals = dsets['tissue type'].value_counts()

vals3 = { "lymphoid": 17, "myeloid": 2, "epithelial":4, "":10.2}
vals3 = pd.Series(vals3)
#vals2 = (vals2)/(sum(vals2)+5)
cmap = plt.colormaps["Blues"]

outer_colors = cmap([100,150,220,1])
outer_colors[3,:] = [1,1,1,1]
#inner_colors = cmap([1, 2, 5, 6, 9, 10])

#ax.pie(dsets['Perturbation'].value_counts(), radius=1, colors=outer_colors,
#       wedgeprops=dict(width=0.3, edgecolor='w'))
ax.pie(vals, radius=1,# colors=outer_colors,
       wedgeprops=dict(width=1, edgecolor='w'))#, labels = vals.index.values)

ax.pie(vals3, radius=1,labels = vals3.index.values, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])

ax.set(aspect="equal", title='Cell types across Datasets')
#plt.legend(labels= vals.index.values, loc="right")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),labels= ["Cell line", "Primary tissue",
                                                             "Stem cells"]) #vals.index.values)

plt.savefig("./figs/nested_grouped.png",bbox_inches='tight')
plt.show()
